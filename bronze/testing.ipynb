# %%
import pypyodbc as odbc
import pandas as pd
import requests
import time

# SQL Server Connection
connection_string = (
    f"DRIVER={{SQL Server}};"
    f"SERVER={r'Akeelah\SQLEXPRESS'};"
    f"DATABASE=Crypto_DataWarehouse;"
    "Trusted_Connection=yes;"
)

# Create connection object
conn = odbc.connect(connection_string)

# Get coins from database - pass connection object instead of string
coins_df = pd.read_sql(
    "SELECT DISTINCT id, name FROM bronze.coin_market WHERE id IS NOT NULL", 
    conn
)

# Fetch OHLC data for all coins
all_data = []
for index, row in coins_df.iterrows():
    coin_id = row['id']
    print(f"Fetching data for {coin_id}...")
    
    try:
            response = requests.get(f'https://api.coingecko.com/api/v3/coins/{coin_id}/ohlc', params={'vs_currency': 'usd', 'days': '365'})
            response.raise_for_status()
            
            coin_df = pd.DataFrame(response.json(), columns=['timestamp', 'open', 'high', 'low', 'close'])
            coin_df['coin_id'] = coin_id
            coin_df['coin_name'] = row.get('name', coin_id)
            coin_df['datetime'] = pd.to_datetime(coin_df['timestamp'], unit='ms')
            all_data.append(coin_df)
            
            print(f"✓ Successfully fetched {len(coin_df)} records for {coin_id}")
            time.sleep(20)
            
    except Exception as e:
            print(f"✗ Error fetching {coin_id}: {e}")
            continue

# Close connection
conn.close()

# Combine all data
ohlc_df = pd.concat(all_data, ignore_index=True) if all_data else pd.DataFrame()

# Display results by coin with separators
if not ohlc_df.empty:
    for coin_id in ohlc_df['coin_id'].unique():
        coin_data = ohlc_df[ohlc_df['coin_id'] == coin_id]
        print(f"\n{'='*80}\nCOIN: {coin_id.upper()} - {coin_data['coin_name'].iloc[0]}\n{'='*80}")
        print(coin_data[['datetime', 'open', 'high', 'low', 'close']].head())
        print(f"Total records: {len(coin_data)}")
        
else:
    print("No data fetched.")
# Out:
# C:\Users\eBay\AppData\Local\Temp\ipykernel_23260\1315061028.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   coins_df = pd.read_sql(
# Fetching data for aave...
# ✓ Successfully fetched 92 records for aave
# Fetching data for avalanche-2...
# ✓ Successfully fetched 92 records for avalanche-2
# Fetching data for binance-bridged-usdt-bnb-smart-chain...
# ✓ Successfully fetched 92 records for binance-bridged-usdt-bnb-smart-chain
# Fetching data for binancecoin...
# ✓ Successfully fetched 92 records for binancecoin
# Fetching data for bitcoin...
# ✓ Successfully fetched 92 records for bitcoin
# Fetching data for bitcoin-cash...
# ✓ Successfully fetched 92 records for bitcoin-cash
# Fetching data for bittensor...
# ✓ Successfully fetched 92 records for bittensor
# Fetching data for canton-network...
# ✓ Successfully fetched 8 records for canton-network
# Fetching data for cardano...
# ✓ Successfully fetched 92 records for cardano
# Fetching data for chainlink...
# ✓ Successfully fetched 92 records for chainlink
# Fetching data for coinbase-wrapped-btc...
# ✓ Successfully fetched 92 records for coinbase-wrapped-btc
# Fetching data for crypto-com-chain...
# ✓ Successfully fetched 92 records for crypto-com-chain
# Fetching data for dai...
# ✓ Successfully fetched 92 records for dai
# Fetching data for dogecoin...
# ✓ Successfully fetched 92 records for dogecoin
# Fetching data for ethena-staked-usde...
# ✓ Successfully fetched 92 records for ethena-staked-usde
# Fetching data for ethena-usde...
# ✓ Successfully fetched 92 records for ethena-usde
# Fetching data for ethereum...
# ✓ Successfully fetched 92 records for ethereum
# Fetching data for figure-heloc...
# ✓ Successfully fetched 27 records for figure-heloc
# Fetching data for hedera-hashgraph...
# ✓ Successfully fetched 92 records for hedera-hashgraph
# Fetching data for hyperliquid...
# ✓ Successfully fetched 92 records for hyperliquid
# Fetching data for leo-token...
# ✓ Successfully fetched 92 records for leo-token
# Fetching data for litecoin...
# ✓ Successfully fetched 92 records for litecoin
# Fetching data for mantle...
# ✓ Successfully fetched 92 records for mantle
# Fetching data for memecore...
# ✓ Successfully fetched 40 records for memecore
# Fetching data for monero...
# ✓ Successfully fetched 92 records for monero
# Fetching data for paypal-usd...
# ✓ Successfully fetched 92 records for paypal-usd
# Fetching data for polkadot...
# ✓ Successfully fetched 92 records for polkadot
# Fetching data for ripple...
# ✓ Successfully fetched 92 records for ripple
# Fetching data for shiba-inu...
# ✓ Successfully fetched 92 records for shiba-inu
# Fetching data for solana...
# ✓ Successfully fetched 92 records for solana
# Fetching data for staked-ether...
# ✓ Successfully fetched 92 records for staked-ether
# Fetching data for stellar...
# ✓ Successfully fetched 92 records for stellar
# Fetching data for sui...
# ✓ Successfully fetched 92 records for sui
# Fetching data for susds...
# ✓ Successfully fetched 91 records for susds
# Fetching data for tether...
# ✓ Successfully fetched 92 records for tether
# Fetching data for the-open-network...
# ✓ Successfully fetched 92 records for the-open-network
# Fetching data for tron...
# ✓ Successfully fetched 92 records for tron
# Fetching data for uniswap...
# ✓ Successfully fetched 92 records for uniswap
# Fetching data for usd1-wlfi...
# ✓ Successfully fetched 61 records for usd1-wlfi
# Fetching data for usd-coin...
# ✓ Successfully fetched 92 records for usd-coin
# Fetching data for usds...
# ✓ Successfully fetched 92 records for usds
# Fetching data for usdt0...
# ✓ Successfully fetched 81 records for usdt0
# Fetching data for weth...
# ✓ Successfully fetched 92 records for weth
# Fetching data for whitebit...
# ✓ Successfully fetched 89 records for whitebit
# Fetching data for world-liberty-financial...
# ✓ Successfully fetched 25 records for world-liberty-financial
# Fetching data for wrapped-beacon-eth...
# ✓ Successfully fetched 92 records for wrapped-beacon-eth
# Fetching data for wrapped-bitcoin...
# ✓ Successfully fetched 92 records for wrapped-bitcoin
# Fetching data for wrapped-eeth...
# ✓ Successfully fetched 92 records for wrapped-eeth
# Fetching data for wrapped-steth...
# ✓ Successfully fetched 92 records for wrapped-steth
# Fetching data for zcash...
# ✓ Successfully fetched 92 records for zcash
#
# ================================================================================
# COIN: AAVE - Aave
# ================================================================================
#     datetime    open    high     low   close
# 0 2024-12-11  259.54  286.89  250.83  273.28
# 1 2024-12-15  274.81  391.90  260.97  366.00
# 2 2024-12-19  365.57  397.54  340.71  340.71
# 3 2024-12-23  340.01  348.72  272.76  316.81
# 4 2024-12-27  317.60  387.27  310.13  337.46
# Total records: 92
# Total unique coin: 1
#
# ================================================================================
# COIN
# Total records: 92
# Total unique coin: 1
#
# ================================================================================
# COIN: WRAPPED-EETH - Wrapped eETH
# ================================================================================
#        datetime     open     high      low    close
# 4010 2024-12-11  3908.19  3978.20  3718.04  3830.15
# 4011 2024-12-15  3828.40  4205.32  3765.84  4075.16
# 4012 2024-12-19  4074.29  4310.42  3816.26  3816.26
# 4013 2024-12-23  3832.24  3919.76  3278.74  3455.86
# 4014 2024-12-27  3457.99  3731.45  3403.55  3511.39
# Total records: 92
# Total unique coin: 1
#
# ================================================================================
# COIN: WRAPPED-STETH - Wrapped stETH
# ================================================================================
#        datetime     open     high      low    close
# 4102 2024-12-11  4390.46  4474.99  4190.92  4320.97
# 4103 2024-12-15  4307.04  4715.78  4242.12  4586.61
# 4104 2024-12-19  4590.29  4824.13  4321.35  4321.35
# 4105 2024-12-23  4331.22  4394.67  3680.21  3887.82
# 4106 2024-12-27  3896.63  4186.28  3845.24  4003.79
# Total records: 92
# Total unique coin: 1
#
# ================================================================================
# COIN: ZCASH - Zcash
# ================================================================================
#        datetime   open   high    low  close
# 4194 2024-12-11  58.61  59.76  54.04  58.98
# 4195 2024-12-15  59.02  67.27  56.73  58.25
# 4196 2024-12-19  58.28  61.26  50.59  50.68
# 4197 2024-12-23  50.57  58.89  41.35  57.47
# 4198 2024-12-27  58.04  77.43  54.96  68.99
# Total records: 92
# Total unique coin: 1

# %%
table_name = "bronze.candle_historical_data"
# SQL Server Connection
connection_string = (
    f"DRIVER={{SQL Server}};"
    f"SERVER={r'Akeelah\SQLEXPRESS'};"
    f"DATABASE=Crypto_DataWarehouse;"
    "Trusted_Connection=yes;"
)

# Create connection object
connection = odbc.connect(connection_string)
sql = (f"""
SELECT coin_id, Max([datetime]) AS last_data_load, COUNT(*) AS number_of_data
FROM {table_name}
GROUP BY coin_id
"""
)
cursor = connection.cursor()


cursor.execute(sql)


all_coin_rows = cursor.fetchall()

all_coin = pd.DataFrame(all_coin_rows, columns=['coin_id','last_data_load', 'number_of_data'])
all_coin
# Out:
# Empty DataFrame
# Columns: [coin_id, last_data_load, number_of_data]
# Index: []

# %%
filtered_coins_less92_datapoint = all_coin[
    (all_coin['coin_id'].isin(ohlc_df['coin_id'])) &
    (all_coin['number_of_data'] < 92)
]
filtered_coins_less92_datapoint
# Out:
# Empty DataFrame
# Columns: [coin_id, last_data_load, number_of_data]
# Index: []

# %%
ohlc_less_92_incremental = (
    ohlc_df
    .merge(filtered_coins_less92_datapoint, on='coin_id', how='left')
)
ohlc_less_92_incremental
# Out:
#           timestamp    open    high     low   close    coin_id  coin_name  \
# 0     1733875200000  259.54  286.89  250.83  273.28       aave       Aave
# 1     1734220800000  274.81  391.90  260.97  366.00       aave       Aave
# 2     1734566400000  365.57  397.54  340.71  340.71       aave       Aave
# 3     1734912000000  340.01  348.72  272.76  316.81       aave       Aave
# 4     1735257600000  317.60  387.27  310.13  337.46       aave       Aave
# ...             ...     ...     ...     ...     ...        ...        ...
# 1778  1763942400000    9.37    9.52    9.04    9.44  leo-token  LEO Token
# 1779  1764288000000    9.49    9.81    9.43    9.78  leo-token  LEO Token
# 1780  1764633600000    9.79    9.91    9.68    9.85  leo-token  LEO Token
# 1781  1764979200000    9.87    9.87    9.11    9.47  leo-token  LEO Token
# 1782  1765324800000    9.47    9.77    9.40    9.63  leo-token  LEO Token
#
#        datetime last_data_load number_of_data
# 0    2024-12-11            NaN            NaN
# 1    2024-12-15            NaN            NaN
# 2    2024-12-19            NaN            NaN
# 3    2024-12-23            NaN            NaN
# 4    2024-12-27            NaN            NaN
# ...         ...            ...            ...
# 1778 2025-11-24            NaN            NaN
# 1779 2025-11-28            NaN            NaN
# 1780 2025-12-02            NaN            NaN
# 1781 2025-12-06            NaN            NaN
# 1782 2025-12-10            NaN            NaN
#
# [1783 rows x 10 columns]

# %%
less_92datapoint_coins
# Out:
# []

# %%
ohlc_new
# Out:
#           timestamp    open    high     low   close coin_id coin_name  \
# 0     1733875200000  259.54  286.89  250.83  273.28    aave      Aave
# 1     1734220800000  274.81  391.90  260.97  366.00    aave      Aave
# 2     1734566400000  365.57  397.54  340.71  340.71    aave      Aave
# 3     1734912000000  340.01  348.72  272.76  316.81    aave      Aave
# 4     1735257600000  317.60  387.27  310.13  337.46    aave      Aave
# ...             ...     ...     ...     ...     ...     ...       ...
# 4281  1763942400000  672.61  713.31  478.39  572.94   zcash     Zcash
# 4282  1764288000000  572.46  590.43  485.75  489.07   zcash     Zcash
# 4283  1764633600000  489.27  489.27  326.75  345.49   zcash     Zcash
# 4284  1764979200000  344.93  403.75  303.31  359.53   zcash     Zcash
# 4285  1765324800000  359.95  447.48  330.25  432.61   zcash     Zcash
#
#        datetime
# 0    2024-12-11
# 1    2024-12-15
# 2    2024-12-19
# 3    2024-12-23
# 4    2024-12-27
# ...         ...
# 4281 2025-11-24
# 4282 2025-11-28
# 4283 2025-12-02
# 4284 2025-12-06
# 4285 2025-12-10
#
# [4286 rows x 8 columns]

# %%
historical_data_less_92_incremental = ohlc_df[
        ohlc_df['coin_id'].isin(filtered_coins_less92_datapoint['coin_id'])]

historical_data_less_92_incremental
# Out:
# Empty DataFrame
# Columns: [timestamp, open, high, low, close, coin_id, coin_name, datetime]
# Index: []

# %%
ohlc_less_92_incremental = (
    ohlc_df
    .merge(filtered_coins_less92_datapoint, on='coin_id', how='left')
)

ohlc_less_92_incremental
# Out:
#           timestamp    open    high     low   close coin_id coin_name  \
# 0     1733875200000  259.54  286.89  250.83  273.28    aave      Aave
# 1     1734220800000  274.81  391.90  260.97  366.00    aave      Aave
# 2     1734566400000  365.57  397.54  340.71  340.71    aave      Aave
# 3     1734912000000  340.01  348.72  272.76  316.81    aave      Aave
# 4     1735257600000  317.60  387.27  310.13  337.46    aave      Aave
# ...             ...     ...     ...     ...     ...     ...       ...
# 4281  1763942400000  672.61  713.31  478.39  572.94   zcash     Zcash
# 4282  1764288000000  572.46  590.43  485.75  489.07   zcash     Zcash
# 4283  1764633600000  489.27  489.27  326.75  345.49   zcash     Zcash
# 4284  1764979200000  344.93  403.75  303.31  359.53   zcash     Zcash
# 4285  1765324800000  359.95  447.48  330.25  432.61   zcash     Zcash
#
#        datetime last_data_load number_of_data
# 0    2024-12-11            NaN            NaN
# 1    2024-12-15            NaN            NaN
# 2    2024-12-19            NaN            NaN
# 3    2024-12-23            NaN            NaN
# 4    2024-12-27            NaN            NaN
# ...         ...            ...            ...
# 4281 2025-11-24            NaN            NaN
# 4282 2025-11-28            NaN            NaN
# 4283 2025-12-02            NaN            NaN
# 4284 2025-12-06            NaN            NaN
# 4285 2025-12-10            NaN            NaN
#
# [4286 rows x 10 columns]

# %%
ohlc_coins = set(ohlc_df['coin_id'])
db_coins = set(all_coin['coin_id'])

new_coins = ohlc_coins - db_coins

less_92datapoint_coins = all_coin[all_coin['number_of_data'] < 92]['coin_id'].tolist()

full_data_coin = all_coin[all_coin['number_of_data'] >= 92]['coin_id'].tolist()

ohlc_new = ohlc_df[ohlc_df['coin_id'].isin(new_coins)]


if not ohlc_new.empty:
    params_list = [
        (
            row['timestamp'], row['open'], row['high'], row['low'], row['close'],
            row['coin_id'], row['coin_name'], row['datetime']
        )
        for _, row in ohlc_new.iterrows()
    ]

    load_query = f'''
    INSERT INTO {table_name} (
        [timestamp], [open], [high], [low], [close],
        coin_id, coin_name, [datetime]
    )
    VALUES (?, ?, ?, ?, ?, ?, ?, ?)
    '''
    cursor.executemany(load_query, params_list)
    connection.commit()
    print(f"🆕 {len(params_list)} rows inserted for new coins")


if  less_92datapoint_coins:

    filtered_coins_less92_datapoint = all_coin[
    (all_coin['coin_id'].isin(ohlc_df['coin_id'])) &
    (all_coin['number_of_data'] < 92)
]
    
    ohlc_less_92_incremental = (
    ohlc_df
    .merge(filtered_coins_less92_datapoint, on='coin_id', how='left')
)
    
    params_list = [
        (
            row['timestamp'], row['open'], row['high'], row['low'], row['close'],
            row['coin_id'], row['coin_name'], row['datetime']
        )
        for _, row in ohlc_less_92_incremental.iterrows()
    ]
    cursor.executemany(load_query, params_list)
    connection.commit()
    print(f"🔄 {len(params_list)} incremental rows inserted for partial coins")
else:
    print("ℹ️ No incremental rows to insert for partial coins")



ohlc_mature = ohlc_df[ohlc_df['coin_id'].isin(full_data_coin)]
if not ohlc_mature.empty:

    delete_earliest_92_datapoint_sql = f"""
    WITH data_occurrence AS (
    SELECT coin_id, COUNT(*) AS number_of_data
    FROM {table_name}
    GROUP BY coin_id
    HAVING COUNT(*) >= 92
),
Ranked AS (
    SELECT *,
           ROW_NUMBER() OVER (PARTITION BY coin_id ORDER BY [datetime] DESC) AS rn
    FROM {table_name}
)
DELETE Ranked
FROM Ranked
JOIN data_occurrence
  ON Ranked.coin_id = data_occurrence.coin_id
WHERE rn = 1
    """
    cursor.execute(delete_earliest_92_datapoint_sql)
    rows = cursor.fetchall()
    selected = len(rows)
    connection.commit()
    print(f"✅ {cursor.rowcount} oldest rows deleted for full data coins")

    
    # Keep only latest row per coin
    ohlc_latest = (
        ohlc_mature
        .sort_values('datetime')
        .groupby('coin_id', as_index=False)
        .tail(1)
    )
    params_list = [
        (
            row['timestamp'], row['open'], row['high'], row['low'], row['close'],
            row['coin_id'], row['coin_name'], row['datetime']
        )
        for _, row in ohlc_latest.iterrows()
    ]
    cursor.executemany(load_query, params_list)
    connection.commit()
    print(f"♻️ {len(params_list)} latest rows inserted for mature coins")

# -----------------------------
# CLOSE CONNECTION
# -----------------------------
cursor.close()
connection.close()
print("All done ✅")
# Out:
# 🆕 4286 rows inserted for new coins
# ℹ️ No incremental rows to insert for partial coins
# All done ✅

# %%
ohlc_coins = set(ohlc_df['coin_id'])
db_coins = set(all_coin['coin_id'])


filtered_coins_92_datapoint = all_coin[
    (all_coin['coin_id'].isin(ohlc_df['coin_id'])) &
    (all_coin['number_of_data'] >= 92)
]

ohlc_latest_92 = (
    filtered_coins_92_datapoint
    .sort_values('datetime')
    .groupby('coin_id', as_index=False)
    .tail(1)
)

filtered_coins_less92_datapoint = all_coin[
    (all_coin['coin_id'].isin(ohlc_df['coin_id'])) &
    (all_coin['number_of_data'] < 92)
]


ohlc_latest_92 = (
    filtered_coins_less92_datapoint
    .sort_values('datetime')
    .groupby('coin_id', as_index=False)
    .tail(1)
)

if not filtered_coins_92_datapoint.empty:
    delete_earliest_92_datapoint_sql = """
    WITH data_occurrence AS (
        SELECT coin_id, COUNT(*) AS number_of_data
        FROM bronze.candle_historical_data
        GROUP BY coin_id
        HAVING COUNT(*) >= 92
    ),
    Ranked AS (
        SELECT *,
               ROW_NUMBER() OVER (PARTITION BY coin_id ORDER BY [datetime] DESC) AS rn
        FROM bronze.candle_historical_data
    )
    SELECT Ranked.*
    FROM Ranked
    JOIN data_occurrence
      ON Ranked.coin_id = data_occurrence.coin_id
    WHERE rn = 1
    """
    cursor.execute(delete_earliest_92_datapoint_sql)
    rows = cursor.fetchall()
    selected = len(rows)
    connection.commit()
    print(f"✅ {selected} latest rows have been selected.")


    

    params_list = [
        (
            row['timestamp'], row['open'], row['high'], row['low'], row['close'],
            row['coin_id'], row['coin_name'], row['datetime']
        )
        for _, row in ohlc_latest_92.iterrows()
    ]

    cursor.executemany(load_query, params_list)
    connection.commit()

    cursor.close()
    connection.close()

    print(f"{len(params_list)} new rows inserted into {table_name} ✅")

    
elif
# Out:
#   Cell In[52], line 71
#     elif
#          ^
# SyntaxError: invalid syntax

# %%
filtered_coins_92_datapoint
# Out:
#                                  coin_id  number_of_data
# 0                           bitcoin-cash              92
# 1                               ethereum              92
# 2                                bitcoin              92
# 3   binance-bridged-usdt-bnb-smart-chain              92
# 4                              chainlink              92
# 5                       crypto-com-chain              92
# 6                     ethena-staked-usde              92
# 7                            binancecoin              92
# 8                               dogecoin              92
# 9                   coinbase-wrapped-btc              92
# 10                      hedera-hashgraph              92
# 12                             bittensor              92
# 13                                   dai              92
# 14                           avalanche-2              92
# 15                             leo-token              92
# 16                           ethena-usde              92
# 17                               cardano              92
# 18                           hyperliquid              92
# 19                                  aave              92
